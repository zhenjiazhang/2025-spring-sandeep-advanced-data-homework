# %% [markdown]
# # Deploying Custom Python Functions in Pandas
#
# **Our real-world challenge:** We have several datasets (Census, SNAP, homeless shelters) that we need to merge together to glean insight. Our challenge is that the columns in common between all the datasets have slightly different data formatting. We have to standardize those values.
#
# We will have to:
# 1. build a custom Python function, with conditional logic, to standardize our data,
# 2. apply that function across multiple columns,
# 3. merge our datasets

# %%
## import library
import pandas as pd

# %% [markdown]
# ## Import relevant data

# %%
## import census data and get sample of 15
dfcensus = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/conditional-conversion/NYC_Census_2020_2010_geotype.csv")
dfcensus.head()
# Out:
#    Year GeoType   Borough  Community District Number  \
# 0  2020      CD    Queens                        407
# 1  2020      CD  Brooklyn                        311
# 2  2020      CD    Queens                        404
# 3  2020      CD    Queens                        408
# 4  2020      CD    Queens                        411
#
#           Community District Name Total Population  Average household size  \
# 0     Queens Community District 7          269,587                    2.75
# 1  Brooklyn Community District 11          198,870                    2.94
# 2     Queens Community District 4          181,025                    3.24
# 3     Queens Community District 8          161,402                    2.76
# 4    Queens Community District 11          122,211                    2.69
#
#   Children  Latino White non-Hispanic Black non-Hispanic    Asian Other race  \
# 0   45,543  48,845             55,882              5,412  154,404      1,575
# 1   42,380  31,489             72,496              2,353   86,067      1,081
# 2   38,213  93,972              9,329              7,679   65,963      1,692
# 3   32,754  29,486             44,302             18,682   60,413      3,200
# 4   21,612  14,460             41,967              2,641   59,980        779
#
#   Two or more races Total housing units Occupied housing units  \
# 0             3,469             102,836                 97,059
# 1             5,384              71,074                 67,236
# 2             2,390              57,748                 55,202
# 3             5,319              59,385                 56,623
# 4             2,384              47,357                 45,204
#
#   Vacant housing units
# 0                5,777
# 1                3,838
# 2                2,546
# 3                2,762
# 4                2,153

# %%
# get info
dfcensus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       59 non-null     int64
#  1   GeoType                    59 non-null     object
#  2   Borough                    59 non-null     object
#  3   Community District Number  59 non-null     int64
#  4   Community District Name    59 non-null     object
#  5   Total Population           59 non-null     object
#  6   Average household size     59 non-null     float64
#  7   Children                   59 non-null     object
#  8   Latino                     59 non-null     object
#  9   White non-Hispanic         59 non-null     object
#  10  Black non-Hispanic         59 non-null     object
#  11  Asian                      59 non-null     object
#  12  Other race                 59 non-null     object
#  13  Two or more races          59 non-null     object
#  14  Total housing units        59 non-null     object
#  15  Occupied housing units     59 non-null     object
#  16  Vacant housing units       59 non-null     object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 8.0+ KB

# %%
## import SNAP benefits and see sample of 15
dfsnap = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/conditional-conversion/SNAP_benefits_borough.csv")
dfsnap
# Out:
#        Month           Boro Community District  BC_SNAP_Recipients  \
# 0     9/1/20      Manhattan                M01                2276
# 1     9/1/20      Manhattan                M02                2994
# 2     9/1/20      Manhattan                M03               37879
# 3     9/1/20      Manhattan                M04               13035
# 4     9/1/20      Manhattan                M05                6159
# ...      ...            ...                ...                 ...
# 1116  3/1/23         Queens                Q13               23430
# 1117  3/1/23         Queens                Q14               31366
# 1118  3/1/23  Staten Island                S01               41354
# 1119  3/1/23  Staten Island                S02               18554
# 1120  3/1/23  Staten Island                S03               13658
#
#       BC_SNAP_Households
# 0                   1799
# 1                   2438
# 2                  26041
# 3                   9802
# 4                   4317
# ...                  ...
# 1116               14876
# 1117               17378
# 1118               22254
# 1119               10695
# 1120                8389
#
# [1121 rows x 5 columns]

# %%
## get info
dfsnap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Month               1121 non-null   object
#  1   Boro                1121 non-null   object
#  2   Community District  1121 non-null   object
#  3   BC_SNAP_Recipients  1121 non-null   int64
#  4   BC_SNAP_Households  1121 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 43.9+ KB

# %%
## import homeless shelter data and get sample of 15
dfshelter = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/conditional-conversion/HomelessShelterbyBorough.csv")
dfshelter
# Out:
#      Report Date        Borough  Community District  Census Type  \
# 0       10/31/20          Bronx                   1  Individuals
# 1       10/31/20          Bronx                   2  Individuals
# 2       10/31/20          Bronx                   3  Individuals
# 3       10/31/20          Bronx                   4  Individuals
# 4       10/31/20          Bronx                   5  Individuals
# ...          ...            ...                 ...          ...
# 3181     3/31/23         Queens                  13  Individuals
# 3182     3/31/23         Queens                  14  Individuals
# 3183     3/31/23  Staten Island                   1  Individuals
# 3184     3/31/23  Staten Island                   2  Individuals
# 3185     3/31/23  Staten Island                   3  Individuals
#
#       Adult Family Commercial Hotel  Adult Family Shelter  Adult Shelter  \
# 0                               NaN                 189.0           73.0
# 1                               NaN                 160.0            0.0
# 2                               NaN                 258.0          218.0
# 3                               NaN                   NaN          206.0
# 4                               NaN                 203.0            0.0
# ...                             ...                   ...            ...
# 3181                            NaN                   NaN          131.0
# 3182                            NaN                 321.0          102.0
# 3183                            NaN                   NaN            NaN
# 3184                            NaN                   NaN            NaN
# 3185                            NaN                   NaN            NaN
#
#       Adult Shelter Commercial Hotel  Family Cluster  \
# 0                              140.0            31.0
# 1                                NaN           204.0
# 2                              123.0            62.0
# 3                               99.0           910.0
# 4                                NaN           755.0
# ...                              ...             ...
# 3181                           895.0             NaN
# 3182                           339.0             NaN
# 3183                             NaN             NaN
# 3184                             NaN             NaN
# 3185                             NaN             NaN
#
#       Family with Children Commercial Hotel  Family with Children Shelter
# 0                                      64.0                        1202.0
# 1                                       NaN                         866.0
# 2                                     115.0                        1295.0
# 3                                       NaN                        2134.0
# 4                                       NaN                        1054.0
# ...                                     ...                           ...
# 3181                                    NaN                         832.0
# 3182                                    NaN                         180.0
# 3183                                    NaN                         135.0
# 3184                                  546.0                           NaN
# 3185                                    NaN                           NaN
#
# [3186 rows x 11 columns]

# %%
## get info
dfshelter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3186 entries, 0 to 3185
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Report Date                            3186 non-null   object
#  1   Borough                                3186 non-null   object
#  2   Community District                     3186 non-null   int64
#  3   Census Type                            3186 non-null   object
#  4   Adult Family Commercial Hotel          80 non-null     float64
#  5   Adult Family Shelter                   802 non-null    float64
#  6   Adult Shelter                          1797 non-null   float64
#  7   Adult Shelter Commercial Hotel         1242 non-null   float64
#  8   Family Cluster                         402 non-null    float64
#  9   Family with Children Commercial Hotel  886 non-null    float64
#  10  Family with Children Shelter           2168 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 273.9+ KB

# %% [markdown]
# #### What are the differences and challenges?

# %% [markdown]
# ## 1. Conditional Statements: decision-making based on conditions
#
# > We want our code to flow based on inputs, calculations and other needs. Without flow control, a program would execute linearly without any logical progression.
# >
# ### A Conditional Statements
#
#
# <img src="https://sandeepmj.github.io/image-host/if-else.png" width="300">

# %%
## Write an expression that evaluates someone's age and decides 
## whether they can be served alcohol

age = 20
if age < 21:
    print ("No booze for you!")
else:
    print("what will you have?")
# Out:
# No booze for you!

# %% [markdown]
# ### More often than not, there are multiple conditions that have to be tested:
# <img src="https://sandeepmj.github.io/image-host/if-elif-else.png" width="300">

# %% [markdown]
# <b>Create a credit rating expression based on the following values</b>
#
# - 300-579: Poor
# - 580-669: Fair
# - 670-739: Good
# - 740-799: Very good
# - 800-850: Excellent
#
# Your output should say "Your credit of (whatever) is (rating)!"

# %%
## code here
credit = 689

if credit <= 579:
    print (f"Your credit of {credit} is Poor")
elif 580 <= credit < 669:
    print (f"Your credit of {credit} is Fair")
elif 670 <= credit < 739:
    print (f"Your credit of {credit} is Good")
elif 740 <= credit < 799:
    print (f"Your credit of {credit} is Very Good")
else:
 print (f"Your credit of {credit} is Excellent")
# Out:
# Your credit of 689 is Good

# %% [markdown]
# ## Tenary Expression
# ```variable = value1 if some_condition else value2```

# %%
## simple credit approved or not approved
age = 42
"what would you liek to drink?" if age >= 21 else "No Booze for you"
# Out:
# 'what would you liek to drink?'

# %% [markdown]
# Multiple Tenary Expression
# variable = (value1 if condition1  (else value2 if condition2 else value3)

# %%
credit = 580

("Not approved" if credit < 669
else "Excellent rate" if credit >= 750
else "You are approved")
# Out:
# 'Not approved'

# %% [markdown]
# ## Functions
#
# The real power in any programming language is the **Function**.
#
# A function is:
#
# * a little block of script (one line or many) that performs specific task or a series of tasks.
# * reusable and helps us make our code DRY.
# * triggered when something "invokes" or "calls" it.
# * ideally modular – it performs a narrow task and you call several functions to perform more complex tasks.

# %% [markdown]
# #### Build a function called myFunction that adds 2 numbers together
# ## it should print ```"The total is (whatever the number is)!"```

# %%
## built it here
def addNumbers(number1, number2):
    total = number1 + number2
    print(f"The total is {total}")

# %%
## Call the using 4 and 5 as the arguments
addNumbers(4,5)
# Out:
# The total is 9

# %% [markdown]
# ### A function with parameters
#
# <img src="https://sandeepmj.github.io/image-host/function-parameters.png">

# %% [markdown]
# ### Calling a function with arguments
#
# ![Screen Shot 2022-01-25 at 7.50.08 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Return Statements
#
# So far we have only printed out values processed by a function.
#
# But we really want to retain the value the function creates.
#
# We can then pass that value to other parts of our calculations and code.

# %%
## let's save our previous function's result in a variable called Calc
some_value = addNumbers(6,4)
# Out:
# The total is 10

# %%
## Print myCalc. What does it hold?
print(some_value)
# Out:
# None

# %%
## what type of data?
type(some_value)
# Out:
# NoneType

# %% [markdown]
# ### The return Statement

# %%
## Tweak our function by adding return statement
## instead of printing a value we want to return a value(or values).

def addNumbers(number1, number2):
    total = number1+ number2
    print(f"The total is {total}")
    return total

# %%
## call the function add_numbers_ret
## and store in variable called myCalc
my_calc = addNumbers(10, 20)
# Out:
# The total is 30

# %%
## print myCalc
my_calc
# Out:
# 30

# %%
## What type is myCalc?
type(my_calc)
# Out:
# int

# %%
## conditioanl credit check and put into function

def creditCheck(credit):
    
    if credit <= 400:
       print (f"Your credit of {credit} is Poor")
    elif 401 <= credit < 669:
       print (f"Your credit of {credit} is Fair")
    elif 670 <= credit < 739:
       print (f"Your credit of {credit} is Good")
    elif 740 <= credit < 799:
       print (f"Your credit of {credit} is Very Good")
    else:
       print (f"Your credit of {credit} is Excellent")

# %%
creditCheck(450)
# Out:
# Your credit of 450 is Fair

# %% [markdown]
# ### Lambda (or anonymous) Functions
#
# * Lambda functions allow you to create a custom calculation.
# * You can then apply this calculation to targeted columns in your Pandas dataframe.
# * Lambda functions, also known as ```anonymous functions```, are considered quick, throwaway functions.

# %% [markdown]
# ### Structure of a Lamba Function
#
#
#  ```lambda arguments: expression```
#
#  A real lambda function:
#
#  ```lambda x: x * 2```
#
#  Compared to:
#  ```def times2(x):
#     return x*2```

# %% [markdown]
# ### Applying Lambdas to Pandas dataframes
#
# * In Pandas, we ```apply()``` lambda expressions to columns.
#
# Here we create a new column by multiplying existing values in each row of a column by 2.
#
# ```df['new_column'] = df['existing_column'].apply(lambda x: x * 2)```

# %%
## create a df with mock data

data = {'firm': ['Bilk Inc.', 'Vine & Co.', 'Kiln Inc.', 'Y & Y Consulting', 'Trending Inc.', "State Insurance"],
   'net_2020': [1150, 2300, 3400, 1500, 6500, 1000 ],
        'net_2021': [1216, 2619, 3701, 1890, 5630, 1099 ]
           }
df = pd.DataFrame(data)

df
# Out:
#                firm  net_2020  net_2021
# 0         Bilk Inc.      1150      1216
# 1        Vine & Co.      2300      2619
# 2         Kiln Inc.      3400      3701
# 3  Y & Y Consulting      1500      1890
# 4     Trending Inc.      6500      5630
# 5   State Insurance      1000      1099

# %%
## create a copy to test something
dfx = df.copy()
dfx
# Out:
#                firm  net_2020  net_2021
# 0         Bilk Inc.      1150      1216
# 1        Vine & Co.      2300      2619
# 2         Kiln Inc.      3400      3701
# 3  Y & Y Consulting      1500      1890
# 4     Trending Inc.      6500      5630
# 5   State Insurance      1000      1099

# %%
## create a col 2022 which increases the col 2021 by 10 percent
dfx["net_2022"] = dfx["net_2021"].apply(lambda x: x *1.1)
dfx
# Out:
#                firm  net_2020  net_2021  net_2022
# 0         Bilk Inc.      1150      1216    1337.6
# 1        Vine & Co.      2300      2619    2880.9
# 2         Kiln Inc.      3400      3701    4071.1
# 3  Y & Y Consulting      1500      1890    2079.0
# 4     Trending Inc.      6500      5630    6193.0
# 5   State Insurance      1000      1099    1208.9

# %% [markdown]
# ### ```apply()``` v. ```vectorization```
#
# In our previous example, our apply function is applied by looping row by row and applying it to each value. This can be highly inefficient.
#
# In our next cell, we simply use ```vectorization``` and it does the entire column or row at one time. This is much more efficient.

# %%
## vectorize
dfx["net_2022_vectorized"] = dfx["net_2021"] * 1.1
dfx
# Out:
#                firm  net_2020  net_2021  net_2022  net_2022_vectorized
# 0         Bilk Inc.      1150      1216    1337.6               1337.6
# 1        Vine & Co.      2300      2619    2880.9               2880.9
# 2         Kiln Inc.      3400      3701    4071.1               4071.1
# 3  Y & Y Consulting      1500      1890    2079.0               2079.0
# 4     Trending Inc.      6500      5630    6193.0               6193.0
# 5   State Insurance      1000      1099    1208.9               1208.9

# %% [markdown]
# ### When Should You Use .apply() Instead?
# - When operations involve multiple columns and require complex logic.
# - We can tap ```lambdas``` using values from specific columns for our calculations
#
# ```df['new_col'] = df.apply(lambda x: x['column1'] + x['column2'], axis = 1)```

# %%
## Find the difference between net_2020 and net_2022
dfx["3-yr-diff"] = dfx.apply(lambda x: x["net_2022"] - x["net_2020"], axis=1)
dfx
# Out:
#                firm  net_2020  net_2021  net_2022  net_2022_vectorized  \
# 0         Bilk Inc.      1150      1216    1337.6               1337.6
# 1        Vine & Co.      2300      2619    2880.9               2880.9
# 2         Kiln Inc.      3400      3701    4071.1               4071.1
# 3  Y & Y Consulting      1500      1890    2079.0               2079.0
# 4     Trending Inc.      6500      5630    6193.0               6193.0
# 5   State Insurance      1000      1099    1208.9               1208.9
#
#    3-yr-diff
# 0      187.6
# 1      580.9
# 2      671.1
# 3      579.0
# 4     -307.0
# 5      208.9

# %%
## try it without axis = 1
## will break
dfx["3-yr-diff"] = dfx.apply(lambda x: x["net_2022"] - x["net_2020"], axis = 1)
dfx
# Out:
#                firm  net_2020  net_2021  net_2022  net_2022_vectorized  \
# 0         Bilk Inc.      1150      1216    1337.6               1337.6
# 1        Vine & Co.      2300      2619    2880.9               2880.9
# 2         Kiln Inc.      3400      3701    4071.1               4071.1
# 3  Y & Y Consulting      1500      1890    2079.0               2079.0
# 4     Trending Inc.      6500      5630    6193.0               6193.0
# 5   State Insurance      1000      1099    1208.9               1208.9
#
#    3-yr-diff
# 0      187.6
# 1      580.9
# 2      671.1
# 3      579.0
# 4     -307.0
# 5      208.9

# %% [markdown]
# ## So what is ```axis = 1``` in Pandas?
#
# Basically, the axis parameter determines whether the operation is applied to rows or columns:
#
# <img src="https://raw.githubusercontent.com/sandeepmj/22spring-advanced-data/main/img/axis.png" width="75%">

# %%
## Axis Summary
axis = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/axis.csv")
axis
# Out:
#      Action             axis=0 (Operate on Rows)  \
# 0   .drop()  Removes a row (affects all columns)
# 1    .sum()      Summarizes down (column totals)
# 2  .apply()      Applies function to each column
#
#            axis=1 (Operate on Columns)
# 0  Removes a column (affects all rows)
# 1       Summarizes across (row totals)
# 2         Applies function to each row

# %% [markdown]
# ### What is the percentage change between net_2021 and net_2022 in dfx?¶

# %% [markdown]
# #### create a function that gets the percent change between two numbers
# NAME YOUR FUNCTION: pct_chg

# %%
## code function here

# %%
## test it here

# %%
## APPLY to your function

# %% [markdown]
# **What's happening** :
#
# - The apply() function is being used with axis=1, meaning it operates row-wise.
# - The ```lambda x:``` function processes each row of dfx, one at a time.
# - The x represents a single row (not the entire DataFrame, just one row at a time).
# - ```x['net_2022']``` and ```x['net_2021']``` extract values from the row.

# %%
## mix in conditional to create new column that says loss or profit
df["net_2022"] = df["net_2021"]*1.1
df
# Out:
#                firm  net_2020  net_2021  net_2022
# 0         Bilk Inc.      1150      1216    1337.6
# 1        Vine & Co.      2300      2619    2880.9
# 2         Kiln Inc.      3400      3701    4071.1
# 3  Y & Y Consulting      1500      1890    2079.0
# 4     Trending Inc.      6500      5630    6193.0
# 5   State Insurance      1000      1099    1208.9

# %%
df["category"] = df.apply(lambda x: "increase" if x["net_2022"] > x["net_2020"]else "decrease", axis = 1)
df
# Out:
#                firm  net_2020  net_2021  net_2022  category
# 0         Bilk Inc.      1150      1216    1337.6  increase
# 1        Vine & Co.      2300      2619    2880.9  increase
# 2         Kiln Inc.      3400      3701    4071.1  increase
# 3  Y & Y Consulting      1500      1890    2079.0  increase
# 4     Trending Inc.      6500      5630    6193.0  decrease
# 5   State Insurance      1000      1099    1208.9  increase

# %% [markdown]
# ## Back to our original goal of standardizing our three dataframes

# %%
## remind us of census data
dfcensus
# Out:
#     Year GeoType        Borough  Community District Number  \
# 0   2020      CD         Queens                        407
# 1   2020      CD       Brooklyn                        311
# 2   2020      CD         Queens                        404
# 3   2020      CD         Queens                        408
# 4   2020      CD         Queens                        411
# 5   2020      CD      Manhattan                        103
# 6   2020      CD         Queens                        402
# 7   2020      CD       Brooklyn                        312
# 8   2020      CD       Brooklyn                        307
# 9   2020      CD         Queens                        412
# 10  2020      CD         Queens                        409
# 11  2020      CD         Queens                        406
# 12  2020      CD         Queens                        413
# 13  2020      CD       Brooklyn                        310
# 14  2020      CD         Queens                        403
# 15  2020      CD       Brooklyn                        315
# 16  2020      CD         Queens                        401
# 17  2020      CD         Queens                        410
# 18  2020      CD      Manhattan                        106
# 19  2020      CD      Manhattan                        108
# 20  2020      CD  Staten Island                        502
# 21  2020      CD      Manhattan                        104
# 22  2020      CD      Manhattan                        107
# 23  2020      CD       Brooklyn                        314
# 24  2020      CD          Bronx                        209
# 25  2020      CD  Staten Island                        501
# 26  2020      CD         Queens                        405
# 27  2020      CD       Brooklyn                        313
# 28  2020      CD       Brooklyn                        302
# 29  2020      CD       Brooklyn                        305
# 30  2020      CD      Manhattan                        101
# 31  2020      CD       Brooklyn                        301
# 32  2020      CD  Staten Island                        503
# 33  2020      CD      Manhattan                        105
# 34  2020      CD      Manhattan                        102
# 35  2020      CD          Bronx                        211
# 36  2020      CD      Manhattan                        109
# 37  2020      CD       Brooklyn                        318
# 38  2020      CD          Bronx                        207
# 39  2020      CD      Manhattan                        111
# 40  2020      CD          Bronx                        210
# 41  2020      CD       Brooklyn                        306
# 42  2020      CD       Brooklyn                        303
# 43  2020      CD       Brooklyn                        304
# 44  2020      CD      Manhattan                        112
# 45  2020      CD       Brooklyn                        308
# 46  2020      CD          Bronx                        208
# 47  2020      CD      Manhattan                        110
# 48  2020      CD         Queens                        414
# 49  2020      CD          Bronx                        212
# 50  2020      CD       Brooklyn                        317
# 51  2020      CD       Brooklyn                        309
# 52  2020      CD          Bronx                        204
# 53  2020      CD          Bronx                        205
# 54  2020      CD       Brooklyn                        316
# 55  2020      CD          Bronx                        206
# 56  2020      CD          Bronx                        201
# 57  2020      CD          Bronx                        203
# 58  2020      CD          Bronx                        202
#
#                Community District Name Total Population  \
# 0          Queens Community District 7          269,587
# 1       Brooklyn Community District 11          198,870
# 2          Queens Community District 4          181,025
# 39             35,311    9,825      1,249             3,778
# 40             31,215    9,142      1,655             2,763
# 41             10,285    8,372        967             6,424
# 42             76,676    7,988      2,542             8,374
# 43             18,163    7,402      1,584             4,088
# 44             13,161    5,751      1,679             4,149
# 45             49,705    5,451      1,467             6,428
# 46             11,247    5,329      1,279             2,655
# 47             67,610    5,048      1,492             5,608
# 48             44,867    3,553      2,355             4,623
# 49             98,995    3,440      3,008             4,531
# 50            127,289    3,036      2,301            10,670
# 51             52,807    2,640      2,279             5,264
# 52             43,227    2,596      1,460             2,109
# 53             34,598    1,888      1,536             1,841
# 54             66,418    1,331      1,145             4,556
# 55             23,765    1,148        936             1,533
# 56             27,765      909        936             1,547
# 57             36,599      518        882             1,572
# 58             13,025      383        507               703
#
#    Total housing units Occupied housing units Vacant housing units
# 0              102,836                 97,059                5,777
# 1               71,074                 67,236                3,838
# 2               57,748                 55,202                2,546
# 3               59,385                 56,623                2,762
# 4               47,357                 45,204                2,153
# 5               82,589                 76,335                6,254
# 6               60,766                 56,413                4,353
# 7               62,782                 58,552                4,230
# 8               45,683                 43,079                2,604
# 9               84,092                 79,827                4,265
# 10              50,877                 48,117                2,760
# 11              56,695                 53,485                3,210
# 12              66,259                 63,211                3,048
# 13              55,768                 52,460                3,308
# 14              59,119                 56,025                3,094
# 15              67,322                 63,097                4,225
# 16              90,547                 85,697                4,850
# 17              43,252                 41,213                2,039
# 18              99,371                 87,186               12,185
# 19             138,922                122,565               16,357
# 20              51,599                 48,690                2,909
# 21              84,357                 75,001                9,356
# 22             126,397                110,770               15,627
# 23              62,254                 59,355                2,899
# 24              68,576                 66,029                2,547
# 25              69,066                 64,940                4,126
# 26              69,416                 65,075                4,341
# 27              46,672                 44,531                2,141
# 28              66,998                 61,221                5,777
# 29              72,381                 68,174                4,207
# 30              41,977                 36,457                5,520
# 31              89,974                 83,353                6,621
# 32              62,782                 59,404                3,378
# 33              42,323                 33,230                9,093
# 34              58,418                 50,806                7,612
# 35              44,864                 42,686                2,178
# 36              44,900                 41,325                3,575
# 37              72,361                 68,523                3,838
# 38              53,180                 50,996                2,184
# 39              54,738                 51,823                2,915
# 40              54,738                 52,169                2,569
# 41              53,365                 49,623                3,742
# 42              72,904                 67,225                5,679
# 43              47,292                 44,036                3,256
# 44              74,722                 71,076                3,646
# 45              49,525                 46,222                3,303
# 46              45,144                 42,569                2,575
# 47              61,629                 57,720                3,909
# 48              47,975                 44,054                3,921
# 49              60,856                 57,603                3,253
# 50              62,636                 58,768                3,868
# 51              41,694                 39,338                2,356
# 52              54,022                 52,006                2,016
# 53              45,814                 44,332                1,482
# 54              36,951                 34,999                1,952
# 55              32,821                 30,906                1,915
# 56              36,896                 35,495                1,401
# 57              34,360                 32,668                1,692
# 58              19,240                 18,381                  859

# %%
dfsnap
# Out:
#        Month           Boro Community District  BC_SNAP_Recipients  \
# 0     9/1/20      Manhattan                M01                2276
# 1     9/1/20      Manhattan                M02                2994
# 2     9/1/20      Manhattan                M03               37879
# 3     9/1/20      Manhattan                M04               13035
# 4     9/1/20      Manhattan                M05                6159
             NaN             NaN
#
#       Family with Children Commercial Hotel  Family with Children Shelter
# 0                                      64.0                        1202.0
# 1                                       NaN                         866.0
# 2                                     115.0                        1295.0
# 3                                       NaN                        2134.0
# 4                                       NaN                        1054.0
# ...                                     ...                           ...
# 3181                                    NaN                         832.0
# 3182                                    NaN                         180.0
# 3183                                    NaN                         135.0
# 3184                                  546.0                           NaN
# 3185                                    NaN                           NaN
#
# [3186 rows x 11 columns]

# %%
dfcensus.head(2)
# Out:
#    Year GeoType   Borough  Community District Number  \
# 0  2020      CD    Queens                        407
# 1  2020      CD  Brooklyn                        311
#
#           Community District Name Total Population  Average household size  \
# 0     Queens Community District 7          269,587                    2.75
# 1  Brooklyn Community District 11          198,870                    2.94
#
#   Children  Latino White non-Hispanic Black non-Hispanic    Asian Other race  \
# 0   45,543  48,845             55,882              5,412  154,404      1,575
# 1   42,380  31,489             72,496              2,353   86,067      1,081
#
#   Two or more races Total housing units Occupied housing units  \
# 0             3,469             102,836                 97,059
# 1             5,384              71,074                 67,236
#
#   Vacant housing units
# 0                5,777
# 1                3,838

# %%
dfcensus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       59 non-null     int64
#  1   GeoType                    59 non-null     object
#  2   Borough                    59 non-null     object
#  3   Community District Number  59 non-null     int64
#  4   Community District Name    59 non-null     object
#  5   Total Population           59 non-null     object
#  6   Average household size     59 non-null     float64
#  7   Children                   59 non-null     object
#  8   Latino                     59 non-null     object
#  9   White non-Hispanic         59 non-null     object
#  10  Black non-Hispanic         59 non-null     object
#  11  Asian                      59 non-null     object
#  12  Other race                 59 non-null     object
#  13  Two or more races          59 non-null     object
#  14  Total housing units        59 non-null     object
#  15  Occupied housing units     59 non-null     object
#  16  Vacant housing units       59 non-null     object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 8.0+ KB

# %% [markdown]
# ### Function fo standardize census CDN

# %%
## function to convert CDN for census data
def convertCensus(cdn):
    string_cdn = str(cdn)
    first_digit = string_cdn[0]
    #print(first_digit)
    last_2_digits = string_cdn[1:3]
    #print(last_2_digits)
    if first_digit == "1":
        cdn_code = f"M{last_2_digits}"
    elif first_digit == "2":
         cdn_code = f"B{last_2_digits}"
    elif first_digit == "3":
         cdn_code = f"K{last_2_digits}"
    elif first_digit == "4":
         cdn_code = f"Q{last_2_digits}"
    elif first_digit == "5":
         cdn_code = f"S{last_2_digits}"
    else: cdn_code = "FLAG"
    return cdn_code

# %%
dfcensus.head(3)
# Out:
#    Year GeoType   Borough  Community District Number  \
# 0  2020      CD    Queens                        407
# 1  2020      CD  Brooklyn                        311
# 2  2020      CD    Queens                        404
#
#           Community District Name Total Population  Average household size  \
# 0     Queens Community District 7          269,587                    2.75
# 1  Brooklyn Community District 11          198,870                    2.94
# 2     Queens Community District 4          181,025                    3.24
#
#   Children  Latino White non-Hispanic Black non-Hispanic    Asian Other race  \
# 0   45,543  48,845             55,882              5,412  154,404      1,575
# 1   42,380  31,489             72,496              2,353   86,067      1,081
# 2   38,213  93,972              9,329              7,679   65,963      1,692
#
#   Two or more races Total housing units Occupied housing units  \
# 0             3,469             102,836                 97,059
# 1             5,384              71,074                 67,236
# 2             2,390              57,748                 55,202
#
#   Vacant housing units
# 0                5,777
# 1                3,838
# 2                2,546

# %%
## run it
convertCensus(519)
# Out:
# 'S19'

# %%
dfcensus["updated_cdn"] = \
dfcensus["Community District Number"].apply(lambda x: convertCensus(x))
dfcensus
# Out:
#     Year GeoType        Borough  Community District Number  \
# 0   2020      CD         Queens                        407
# 1   2020      CD       Brooklyn                        311
# 2   2020      CD         Queens                        404
# 3   2020      CD         Queens                        408
# 4   2020      CD         Queens                        411
# 5   2020      CD      Manhattan                        103
# 6   2020      CD         Queens                        402
# 7   2020      CD       Brooklyn                        312
# 8   2020      CD       Brooklyn                        307
# 9   2020      CD         Queens                        412
# 10  2020      CD         Queens                        409
# 11  2020      CD         Queens                        406
# 12  2020      CD         Queens                        413
# 13  2020      CD       Brooklyn                        310
# 14  2020      CD         Queens                        403
# 15  2020      CD       Brooklyn                        315
# 16  2020      CD         Queens                        401
# 17  2020      CD         Queens                        410
# 18  2020      CD      Manhattan                        106
# 19  2020      CD      Manhattan                        108
# 20  2020      CD  Staten Island                        502
# 21  2020      CD      Manhattan                        104
# 22  2020      CD      Manhattan                        107
# 23  2020      CD       Brooklyn                        314
# 24  2020      CD          Bronx                        209
# 25  2020      CD  Staten Island                        501
# 26  2020      CD         Queens                        405
# 27  2020      CD       Brooklyn                        313
# 28  2020      CD       Brooklyn                        302
# 29  2020      CD       Brooklyn                        305
# 30  2020      CD      Manhattan                        101
# 31  2020      CD       Brooklyn                        301
# 32  2020      CD  Staten Island                        503
# 33  2020      CD      Manhattan                        105
# 34  2020      CD      Manhattan                        102
# 35  2020      CD          Bronx                        211
# 36  2020      CD      Manhattan                        109
# 37  2020      CD       Brooklyn                        318
# 38  2020      CD          Bronx                        207
# 39  2020      CD      Manhattan                        111
# 40  2020      CD          Bronx                        210
# 41  2020      CD       Brooklyn                        306
# 42  2020      CD       Brooklyn                        303
# 43  2020      CD       Brooklyn                        304
# 44  2020      CD      Manhattan                        112
# 45  2020      CD       Brooklyn                        308
# 46  2020      CD          Bronx                        208
# 47  2020      CD      Manhattan                        110
# 48  2020      CD         Queens                        414
# 49  2020      CD          Bronx                        212
# 50  2020      CD       Brooklyn                        317
# 51  2020      CD       Brooklyn                        309
# 52  2020      CD          Bronx                        204
# 53  2020      CD          Bronx                        205
# 54  2020      CD       Brooklyn                        316
# 55  2020      CD          Bronx                        206
# 56  2020      CD          Bronx                        201
# 57  2020      CD          Bronx                        203
# 58  2020      CD          Bronx                        202
#
#                Community District Name Total Population  \
# 0          Queens Community District 7          269,587
# 1       Brooklyn Community District 11          198,870
# 2          Queens Community District 4          181,025
# 3          Queens Community District 8          161,402
# 4         Queens Community District 11          122,211
# 5       Manhattan Community District 3          163,141
# 6          Queens Community District 2          137,981
# 7       Brooklyn Community District 12          205,377
# 8        Brooklyn Community District 7          133,230
# 9         Queens Community District 12          256,278
# 10         Queens Community District 9          152,839
# 11         Queens Community District 6          120,955
# 12        Queens Community District 13          199,218
# 13      Brooklyn Community District 10          136,071
# 49             98,995    3,440      3,008             4,531
# 50            127,289    3,036      2,301            10,670
# 51             52,807    2,640      2,279             5,264
# 52             43,227    2,596      1,460             2,109
# 53             34,598    1,888      1,536             1,841
# 54             66,418    1,331      1,145             4,556
# 55             23,765    1,148        936             1,533
# 56             27,765      909        936             1,547
# 57             36,599      518        882             1,572
# 58             13,025      383        507               703
#
#    Total housing units Occupied housing units Vacant housing units updated_cdn
# 0              102,836                 97,059                5,777         Q07
# 1               71,074                 67,236                3,838         K11
# 2               57,748                 55,202                2,546         Q04
# 3               59,385                 56,623                2,762         Q08
# 4               47,357                 45,204                2,153         Q11
# 5               82,589                 76,335                6,254         M03
# 6               60,766                 56,413                4,353         Q02
# 7               62,782                 58,552                4,230         K12
# 8               45,683                 43,079                2,604         K07
# 9               84,092                 79,827                4,265         Q12
# 10              50,877                 48,117                2,760         Q09
# 11              56,695                 53,485                3,210         Q06
# 12              66,259                 63,211                3,048         Q13
# 13              55,768                 52,460                3,308         K10
# 14              59,119                 56,025                3,094         Q03
# 15              67,322                 63,097                4,225         K15
# 16              90,547                 85,697                4,850         Q01
# 17              43,252                 41,213                2,039         Q10
# 18              99,371                 87,186               12,185         M06
# 19             138,922                122,565               16,357         M08
# 20              51,599                 48,690                2,909         S02
# 21              84,357                 75,001                9,356         M04
# 22             126,397                110,770               15,627         M07
# 23              62,254                 59,355                2,899         K14
# 24              68,576                 66,029                2,547         B09
# 25              69,066                 64,940                4,126         S01
# 26              69,416                 65,075                4,341         Q05
# 27              46,672                 44,531                2,141         K13
# 28              66,998                 61,221                5,777         K02
# 29              72,381                 68,174                4,207         K05
# 30              41,977                 36,457                5,520         M01
# 31              89,974                 83,353                6,621         K01
# 32              62,782                 59,404                3,378         S03
# 33              42,323                 33,230                9,093         M05
# 34              58,418                 50,806                7,612         M02
# 35              44,864                 42,686                2,178         B11
# 36              44,900                 41,325                3,575         M09
# 37              72,361                 68,523                3,838         K18
# 38              53,180                 50,996                2,184         B07
# 39              54,738                 51,823                2,915         M11
# 40              54,738                 52,169                2,569         B10
# 41              53,365                 49,623                3,742         K06
# 42              72,904                 67,225                5,679         K03
# 43              47,292                 44,036                3,256         K04
# 44              74,722                 71,076                3,646         M12
# 45              49,525                 46,222                3,303         K08
# 46              45,144                 42,569                2,575         B08
# 47              61,629                 57,720                3,909         M10
# 48              47,975                 44,054                3,921         Q14
# 49              60,856                 57,603                3,253         B12
# 50              62,636                 58,768                3,868         K17
# 51              41,694                 39,338                2,356         K09
# 52              54,022                 52,006                2,016         B04
# 53              45,814                 44,332                1,482         B05
# 54              36,951                 34,999                1,952         K16
# 55              32,821                 30,906                1,915         B06
# 56              36,896                 35,495                1,401         B01
# 57              34,360                 32,668                1,692         B03
# 58              19,240                 18,381                  859         B02

# %%
## did it work?

# %%
## let's move it closer to original CDN

# %%
## reorder
list(dfcensus.columns)
# Out:
# ['Year',
#  'GeoType',
#  'Borough',
#  'Community District Number',
#  'Community District Name',
#  'Total Population',
#  'Average household size',
#  'Children',
#  'Latino',
#  'White non-Hispanic',
#  'Black non-Hispanic',
#  'Asian',
#  'Other race',
#  'Two or more races',
#  'Total housing units',
#  'Occupied housing units',
#  'Vacant housing units',
#  'updated_cdn']

# %%
## call census data
dfcensus = dfcensus[['Year',
 'GeoType',
 'Borough',
    'updated_cdn',
 'Total Population',
 'Average household size',
 'Children',
 'Latino',
 'White non-Hispanic',
 'Black non-Hispanic',
 'Asian',
 'Other race',
 'Two or more races',
 'Total housing units',
 'Occupied housing units',
 'Vacant housing units',
]]
dfcensus
# Out:
#     Year GeoType        Borough updated_cdn Total Population  \
# 0   2020      CD         Queens         Q07          269,587
# 1   2020      CD       Brooklyn         K11          198,870
# 2   2020      CD         Queens         Q04          181,025
# 3   2020      CD         Queens         Q08          161,402
# 4   2020      CD         Queens         Q11          122,211
# 5   2020      CD      Manhattan         M03          163,141
# 6   2020      CD         Queens         Q02          137,981
# 7   2020      CD       Brooklyn         K12          205,377
# 8   2020      CD       Brooklyn         K07          133,230
# 9   2020      CD         Queens         Q12          256,278
# 10  2020      CD         Queens         Q09          152,839
# 11  2020      CD         Queens         Q06          120,955
# 12  2020      CD         Queens         Q13          199,218
# 13  2020      CD       Brooklyn         K10          136,071
# 14  2020      CD         Queens         Q03          179,134
# 15  2020      CD       Brooklyn         K15          169,632
# 16  2020      CD         Queens         Q01          196,803
# 17  2020      CD         Queens         Q10          129,411
# 18  2020      CD      Manhattan         M06          155,614
# 19  2020      CD      Manhattan         M08          231,983
# 20  2020      CD  Staten Island         S02          140,795
# 21  2020      CD      Manhattan         M04          131,351
# 22  2020      CD      Manhattan         M07          222,129
# 23  2020      CD       Brooklyn         K14          164,568
# 24  2020      CD          Bronx         B09          188,249
# 25  2020      CD  Staten Island         S01          189,663
# 26  2020      CD         Queens         Q05          178,178
# 27  2020      CD       Brooklyn         K13          108,905
# 28  2020      CD       Brooklyn         K02          130,021
# 29  2020      CD       Brooklyn         K05          200,293
# 30  2020      CD      Manhattan         M01           78,390
# 31  2020      CD       Brooklyn         K01          204,125
# 32  2020      CD  Staten Island         S03          164,723
# 33  2020      CD      Manhattan         M05           63,600
# 34  2020      CD      Manhattan         M02           92,445
# 35  2020      CD          Bronx         B11          119,666
# 36  2020      CD      Manhattan         M09          110,458
# 37  2020      CD       Brooklyn         K18          204,095
# 38  2020      CD          Bronx         B07          146,813
# 39  2020      CD      Manhattan         M11          125,771
# 40  2020      CD          Bronx         B10          130,763
# 41  2020      CD       Brooklyn         K06          113,933
# 42  2020      CD       Brooklyn         K03          174,960
# 43  2020      CD       Brooklyn         K04          120,747
# 44  2020      CD      Manhattan         M12          180,206
# 45  2020      CD       Brooklyn         K08          108,259
# 46  2020      CD          Bronx         B08          106,924
# 47  2020      CD      Manhattan         M10          130,440
# 48  2020      CD         Queens         Q14          124,173
# 49  2020      CD          Bronx         B12          163,489
# 50  2020      CD       Brooklyn         K17          162,446
# 51  2020      CD       Brooklyn         K09          102,000
# 52  2020      CD          Bronx         B04          150,436
# 53  2020      CD          Bronx         B05          132,584
# 54  2020      CD       Brooklyn         K16           98,506
# 32              62,782                 59,404                3,378
# 33              42,323                 33,230                9,093
# 34              58,418                 50,806                7,612
# 35              44,864                 42,686                2,178
# 36              44,900                 41,325                3,575
# 37              72,361                 68,523                3,838
# 38              53,180                 50,996                2,184
# 39              54,738                 51,823                2,915
# 40              54,738                 52,169                2,569
# 41              53,365                 49,623                3,742
# 42              72,904                 67,225                5,679
# 43              47,292                 44,036                3,256
# 44              74,722                 71,076                3,646
# 45              49,525                 46,222                3,303
# 46              45,144                 42,569                2,575
# 47              61,629                 57,720                3,909
# 48              47,975                 44,054                3,921
# 49              60,856                 57,603                3,253
# 50              62,636                 58,768                3,868
# 51              41,694                 39,338                2,356
# 52              54,022                 52,006                2,016
# 53              45,814                 44,332                1,482
# 54              36,951                 34,999                1,952
# 55              32,821                 30,906                1,915
# 56              36,896                 35,495                1,401
# 57              34,360                 32,668                1,692
# 58              19,240                 18,381                  859

# %% [markdown]
# ## Homework
# ### Standardize shelter data

# %%
## recall dfshelter
dfshelter
# Out:
#      Report Date        Borough  Community District  Census Type  \
# 0       10/31/20          Bronx                   1  Individuals
# 1       10/31/20          Bronx                   2  Individuals
# 2       10/31/20          Bronx                   3  Individuals
# 3       10/31/20          Bronx                   4  Individuals
# 4       10/31/20          Bronx                   5  Individuals
# ...          ...            ...                 ...          ...
# 3181     3/31/23         Queens                  13  Individuals
# 3182     3/31/23         Queens                  14  Individuals
# 3183     3/31/23  Staten Island                   1  Individuals
# 3184     3/31/23  Staten Island                   2  Individuals
# 3185     3/31/23  Staten Island                   3  Individuals
#
#       Adult Family Commercial Hotel  Adult Family Shelter  Adult Shelter  \
# 0                               NaN                 189.0           73.0
# 1                               NaN                 160.0            0.0
# 2                               NaN                 258.0          218.0
# 3                               NaN                   NaN          206.0
# 4                               NaN                 203.0            0.0
# ...                             ...                   ...            ...
# 3181                            NaN                   NaN          131.0
# 3182                            NaN                 321.0          102.0
# 3183                            NaN                   NaN            NaN
# 3184                            NaN                   NaN            NaN
# 3185                            NaN                   NaN            NaN
#
#       Adult Shelter Commercial Hotel  Family Cluster  \
# 0                              140.0            31.0
# 1                                NaN           204.0
# 2                              123.0            62.0
# 3                               99.0           910.0
# 4                                NaN           755.0
# ...                              ...             ...
# 3181                           895.0             NaN
# 3182                           339.0             NaN
# 3183                             NaN             NaN
# 3184                             NaN             NaN
# 3185                             NaN             NaN
#
#       Family with Children Commercial Hotel  Family with Children Shelter
# 0                                      64.0                        1202.0
# 1                                       NaN                         866.0
# 2                                     115.0                        1295.0
# 3                                       NaN                        2134.0
# 4                                       NaN                        1054.0
# ...                                     ...                           ...
# 3181                                    NaN                         832.0
# 3182                                    NaN                         180.0
# 3183                                    NaN                         135.0
# 3184                                  546.0                           NaN
# 3185                                    NaN                           NaN
#
# [3186 rows x 11 columns]

# %%
dfshelter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3186 entries, 0 to 3185
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Report Date                            3186 non-null   object
#  1   Borough                                3186 non-null   object
#  2   Community District                     3186 non-null   int64
#  3   Census Type                            3186 non-null   object
#  4   Adult Family Commercial Hotel          80 non-null     float64
#  5   Adult Family Shelter                   802 non-null    float64
#  6   Adult Shelter                          1797 non-null   float64
#  7   Adult Shelter Commercial Hotel         1242 non-null   float64
#  8   Family Cluster                         402 non-null    float64
#  9   Family with Children Commercial Hotel  886 non-null    float64
#  10  Family with Children Shelter           2168 non-null   float64
#  11  BoroCD                                 3186 non-null   object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 298.8+ KB

# %%
## function to convert shelter CDN
def convertShelter(cdn):
    string_cdn = str(cdn)
    parts = string_cdn.split()
    
    if len(parts) != 2:
        return "Flag"  # Handle unexpected format
    
    borough_code = parts[0]
    number = parts[1]
    
    if not number.isdigit():
        return "Flag"  # Ensure the second part is a number

    formatted_number = number.zfill(2)  # Pad with leading zero if needed

    if borough_code == "Bronx":
        cdn_code = f"B{formatted_number}"
    elif borough_code == "Brooklyn":
        cdn_code = f"K{formatted_number}"
    elif borough_code == "Manhattan":
        cdn_code = f"M{formatted_number}"
    elif borough_code == "Queens":
        cdn_code = f"Q{formatted_number}"
    elif borough_code == "Staten Island":
        cdn_code = f"S{formatted_number}"
    else:
        cdn_code = "Flag"
    
    return cdn_code

# %%
## test it
convertShelter("Queens 13")
# Out:
# 'Q13'

# %%
## use on shelter data

# %%
## verify
dfshelter["updated_cdn"] = \
dfshelter["Community District"].apply(lambda x: convertShelter(x))
dfshelter
# Out:
#      Report Date        Borough  Community District  Census Type  \
# 0       10/31/20          Bronx                   1  Individuals
# 1       10/31/20          Bronx                   2  Individuals
# 2       10/31/20          Bronx                   3  Individuals
# 3       10/31/20          Bronx                   4  Individuals
# 4       10/31/20          Bronx                   5  Individuals
# ...          ...            ...                 ...          ...
# 3181     3/31/23         Queens                  13  Individuals
# 3182     3/31/23         Queens                  14  Individuals
# 3183     3/31/23  Staten Island                   1  Individuals
# 3184     3/31/23  Staten Island                   2  Individuals
# 3185     3/31/23  Staten Island                   3  Individuals
#
#       Adult Family Commercial Hotel  Adult Family Shelter  Adult Shelter  \
# 0                               NaN                 189.0           73.0
# 1                               NaN                 160.0            0.0
# 2                               NaN                 258.0          218.0
# 3                               NaN                   NaN          206.0
# 4                               NaN                 203.0            0.0
# ...                             ...                   ...            ...
# 3181                            NaN                   NaN          131.0
# 3182                            NaN                 321.0          102.0
# 3183                            NaN                   NaN            NaN
# 3184                            NaN                   NaN            NaN
# 3185                            NaN                   NaN            NaN
#
#       Adult Shelter Commercial Hotel  Family Cluster  \
# 0                              140.0            31.0
# 1                                NaN           204.0
# 2                              123.0            62.0
# 3                               99.0           910.0
# 4                                NaN           755.0
# ...                              ...             ...
# 3181                           895.0             NaN
# 3182                           339.0             NaN
# 3183                             NaN             NaN
# 3184                             NaN             NaN
# 3185                             NaN             NaN
#
#       Family with Children Commercial Hotel  Family with Children Shelter  \
# 0                                      64.0                        1202.0
# 1                                       NaN                         866.0
# 2                                     115.0                        1295.0
# 3                                       NaN                        2134.0
# 4                                       NaN                        1054.0
# ...                                     ...                           ...
# 3181                                    NaN                         832.0
# 3182                                    NaN                         180.0
# 3183                                    NaN                         135.0
# 3184                                  546.0                           NaN
# 3185                                    NaN                           NaN
#
#      BoroCD updated_cdn
# 0      Flag        Flag
# 1      Flag        Flag
# 2      Flag        Flag
# 3      Flag        Flag
# 4      Flag        Flag
# ...     ...         ...
# 3181   Flag        Flag
# 3182   Flag        Flag
# 3183   Flag        Flag
# 3184   Flag        Flag
# 3185   Flag        Flag
#
# [3186 rows x 13 columns]

# %% [markdown]
# #### Reorder columns

# %%
## call columns into list
list(dfshelter.columns)
# Out:
# ['Report Date',
#  'Borough',
#  'Community District',
#  'Census Type',
#  'Adult Family Commercial Hotel',
#  'Adult Family Shelter',
#  'Adult Shelter',
#  'Adult Shelter Commercial Hotel',
#  'Family Cluster',
#  'Family with Children Commercial Hotel',
#  'Family with Children Shelter',
#  'BoroCD',
#  'updated_cdn']

# %%
## redorder and call
dfshelter = dfshelter[['Report Date',
 'updated_cdn',                     
 'Census Type',
 'Adult Family Commercial Hotel',
 'Adult Family Shelter',
 'Adult Shelter',
 'Adult Shelter Commercial Hotel',
 'Family Cluster',
 'Family with Children Commercial Hotel',
 'Family with Children Shelter',
]]
dfshelter
# Out:
#      Report Date updated_cdn updated_cdn  Census Type  \
# 0       10/31/20        Flag        Flag  Individuals
# 1       10/31/20        Flag        Flag  Individuals
# 2       10/31/20        Flag        Flag  Individuals
# 3       10/31/20        Flag        Flag  Individuals
# 4       10/31/20        Flag        Flag  Individuals
# ...          ...         ...         ...          ...
# 3181     3/31/23        Flag        Flag  Individuals
# 3182     3/31/23        Flag        Flag  Individuals
# 3183     3/31/23        Flag        Flag  Individuals
# 3184     3/31/23        Flag        Flag  Individuals
# 3185     3/31/23        Flag        Flag  Individuals
#
#       Adult Family Commercial Hotel  Adult Family Shelter  Adult Shelter  \
# 0                               NaN                 189.0           73.0
# 1                               NaN                 160.0            0.0
# 2                               NaN                 258.0          218.0
# 3                               NaN                   NaN          206.0
# 4                               NaN                 203.0            0.0
# ...                             ...                   ...            ...
# 3181                            NaN                   NaN          131.0
# 3182                            NaN                 321.0          102.0
# 3183                            NaN                   NaN            NaN
# 3184                            NaN                   NaN            NaN
# 3185                            NaN                   NaN            NaN
#
#       Adult Shelter Commercial Hotel  Family Cluster  \
# 0                              140.0            31.0
# 1                                NaN           204.0
# 2                              123.0            62.0
# 3                               99.0           910.0
# 4                                NaN           755.0
# ...                              ...             ...
# 3181                           895.0             NaN
# 3182                           339.0             NaN
# 3183                             NaN             NaN
# 3184                             NaN             NaN
# 3185                             NaN             NaN
#
#       Family with Children Commercial Hotel  Family with Children Shelter
# 0                                      64.0                        1202.0
# 1                                       NaN                         866.0
# 2                                     115.0                        1295.0
# 3                                       NaN                        2134.0
# 4                                       NaN                        1054.0
# ...                                     ...                           ...
# 3181                                    NaN                         832.0
# 3182                                    NaN                         180.0
# 3183                                    NaN                         135.0
# 3184                                  546.0                           NaN
# 3185                                    NaN                           NaN
#
# [3186 rows x 11 columns]

# %% [markdown]
# ## WILL DO IN CLASS Merge dataframes

# %%
#call a few rows of census

# %%
#call a few rows of snap

# %%
## merge 2 at a time

# %%
## Homework 
## merge shelter into previous dataframe

# %%
## call shelter data

# %%
## instead of 2 at a time, we do in one go:
df = dfcensus.merge(dfsnap, on = "updated_cdn").merge(dfshelter, on = "updated_cdn")
df

# %%
df.info()
